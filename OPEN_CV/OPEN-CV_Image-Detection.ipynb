# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
src = cv2.imread('taekwonv1.jpg')

plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 케니엣지 검출
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# 하위 임계값 100, 상위 임계값 200, 마스크 크기 3, L2_norm
dst = cv2.Canny(src, threshold1=100, threshold2=200, apertureSize=3, L2gradient=True)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
# cv2.imshow('dst', dst)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# 소벨 미분
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# dst = cv2.Sobel(src, ddepth= , dx=0 , dy=0, ksize=0, scale= , delta= , borderType=)
dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=1 , dy=1, ksize= 3)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 소벨 미분 2
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=0 , dy=1, ksize= 3)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 소벨 미분 3
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=1 , dy=0, ksize= 3)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 소벨 미분 4
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=1 , dy=1, ksize= 7)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 소벨 미분 5
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=1 , dy=1, ksize= 29)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 소벨 미분 6
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

dst = cv2.Sobel(src, ddepth=cv2.CV_32F, dx=2 , dy=2, ksize= 3)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 샤르 필터
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# dst = cv2.Scharr(src, ddepth= , dx=0 , dy=0, scale= , delta= , borderType=)
dst = cv2.Scharr(src, ddepth=cv2.CV_32F, dx=1 , dy=1)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-50-d69f51405a1a> in <module>
#       3
#       4 # dst = cv2.Scharr(src, ddepth= , dx=0 , dy=0, scale= , delta= , borderType=)
# ----> 5 dst = cv2.Scharr(src, ddepth=cv2.CV_32F, dx=1 , dy=1)
#       6
#       7 plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\deriv.cpp:67: error: (-215:Assertion failed) dx >= 0 && dy >= 0 && dx+dy == 1 in function 'cv::getScharrKernels'

# %%
# 라플라시안 필터
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# dst = cv2.Laplacian(src, ddepth= , ksize= , scale= , delta= , borderType=)
dst = cv2.Laplacian(src, ddepth=cv2.CV_32F, ksize=1)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 라플라시안 필터 1
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# dst = cv2.Laplacian(src, ddepth= , ksize= , scale= , delta= , borderType=)
dst = cv2.Laplacian(src, ddepth=cv2.CV_32F, ksize=7)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 라플라시안 필터 2
src = cv2.imread('taekwonv1.jpg', cv2.IMREAD_GRAYSCALE)

# dst = cv2.Laplacian(src, ddepth= , ksize= , scale= , delta= , borderType=)
dst = cv2.Laplacian(src, ddepth=cv2.CV_32F, ksize=15)

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_RGB2BGR))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
src = cv2.imread('taekwonv1.jpg')
dst = src.copy()

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))

gray = cv2.cvtColor(src, cv2.COLOR_RGB2GRAY)
ret, binary = cv2.threshold(gray, thresh=230, maxval=255, type=cv2.THRESH_BINARY)
morp = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel, iterations=2)
image = cv2.bitwise_not(morp)

contours, hierarchy = cv2.findContours(image, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
cv2.drawContours(dst, contours=contours, contourIdx=-1, color=(0,0,255), thickness=3)

for i in range(len(contours)):
    cv2.putText(dst, str(i), tuple(contours[i][0][0]), cv2.FONT_HERSHEY_COMPLEX, 1.3, (255,0,0), 1)
    print(i, hierarchy[0][i])
    
cv2.imshow('dst', dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0 [-1 -1  1 -1]
# 1 [ 2 -1 -1  0]
# 2 [ 3  1 -1  0]
# 3 [ 4  2 -1  0]
# 4 [ 5  3 -1  0]
# 5 [ 6  4 -1  0]
# 6 [ 7  5 -1  0]
# 7 [ 8  6 -1  0]
# 8 [ 9  7 -1  0]
# 9 [10  8 -1  0]
# 10 [11  9 -1  0]
# 11 [12 10 -1  0]
# 12 [-1 11 -1  0]

# %%
contours
# Out:
# [array([[[0, 0]],
#
#         [[0, 1]],
#
#         [[0, 2]],
#
#         ...,
#
#         [[3, 0]],
#
#         [[2, 0]],
#
#         [[1, 0]]], dtype=int32), array([[[261, 306]],
#
#         [[262, 305]],
#
#         [[263, 306]],
#
#         [[262, 307]]], dtype=int32), array([[[299, 304]],
#
#         [[300, 303]],
#
#         [[301, 304]],
#
#         [[300, 305]]], dtype=int32), array([[[260, 299]],
#
#         [[261, 298]],
#
#         [[262, 299]],
#
#         [[262, 300]],
#
#         [[261, 301]],
#
#         [[260, 300]]], dtype=int32), array([[[252, 295]],
#
#         [[253, 294]],
#
#         [[254, 295]],
#
#         [[254, 296]],
#
#         [[253, 297]],
#
#         [[252, 296]]], dtype=int32), array([[[251, 294]],
#
#         [[252, 293]],
#
#         [[253, 294]],
#
#         [[252, 295]]], dtype=int32), array([[[250, 293]],
#
#         [[251, 292]],
#
#         [[252, 293]],
#
#         [[251, 294]]], dtype=int32), array([[[300, 292]],
#
#         [[301, 291]],
#
# ...
