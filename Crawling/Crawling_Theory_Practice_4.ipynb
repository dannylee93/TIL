# %%
import requests
from bs4 import BeautifulSoup

URL = "https://finance.naver.com/item/main.nhn?code=005930"

samsung_electronic = requests.get(URL)
html = samsung_electronic.text          # 이건 왜 텍스트로 받았지?

soup = BeautifulSoup(html, 'html.parser')

finance_html = soup.select('div.section.cop_analysis div.sub_section')[0]   
# css selector를 통해서 받아 리스트화 함 >> 내가 선택한 테이블(하위까지 다) 선택해서 함

th_data = [item.get_text().strip() for item in finance_html.select('thead th')] # thead 태그에 속한 th 태그 다 보여줘
annual_date = th_data[3:7]  # 연간실적 4개
quarter_date = th_data[7:13] # 분기실적 6개

finance_index = [item.get_text().strip() for item in finance_html.select('th.h_th2')][3:]
# 행 제목 위치가 th 태그의 h_th2클래스에 있었음

finance_data = [item.get_text().strip() for item in finance_html.select('td')]
# 출력하고싶은 데이터들의 위치가 td에 있었음


import numpy as np

finance_data = np.array(finance_data)
finance_data.resize(len(finance_index), 10)

finance_date = annual_date + quarter_date

import pandas as pd
finance = pd.DataFrame(data=finance_data[0:,0:], index=finance_index, columns=finance_date)

annual_finance = finance.iloc[:, :4]  # 전체 문서에서 iloc[행첨부터 끝까지 , 첨부터 5번째 까지]
quarter_finance = finance.iloc[:, 4:]# 전체 문서에서 iloc[행첨부터 끝까지 , 5번째 부터 끝까지]

# %%
finance
# Out:
#              2016.12    2017.12    2018.12 2019.12(E)    2018.09    2018.12  \
# 매출액        2,018,667  2,395,754  2,437,714  2,315,239    654,600    592,650
# 영업이익         292,407    536,450    588,867    271,494    175,749    108,006
# 당기순이익        227,261    421,867    443,449    219,523    131,507     84,622
# 영업이익률          14.49      22.39      24.16      11.73      26.85      18.22
# 순이익률           11.26      17.61      18.19       9.48      20.09      14.28
# ROE(지배주주)      12.48      21.01      19.63       8.77      21.73      19.63
# 부채비율           35.87      40.68      36.97                 39.28      36.97
# 당좌비율          223.46     181.61     204.12                198.16     204.12
# 유보율        22,004.14  24,536.12  27,531.92             27,412.63  27,531.92
# EPS(원)         2,735      5,421      6,024      3,194      1,771      1,163
# PER(배)         13.18       9.40       6.42      17.53       7.17       6.42
# ...

# %%
th_data = [item.get_text().strip() for item in finance_html.select('thead th')]
th_data
# Out:
# ['주요재무정보',
#  '최근 연간 실적',
#  '최근 분기 실적',
#  '2016.12',
#  '2017.12',
#  '2018.12',
#  '2019.12(E)',
#  '2018.09',
#  '2018.12',
#  '2019.03',
#  '2019.06',
#  '2019.09',
#  '2019.12(E)',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결',
#  'IFRS연결']

# %%
finance_index = [item.get_text().strip() for item in finance_html.select('th.h_th2')]
print(finance_index)
# 행 제목 위치가 th 태그의 h_th2클래스에 있었음
# Out:
# ['주요재무정보', '최근 연간 실적', '최근 분기 실적', '매출액', '영업이익', '당기순이익', '영업이익률', '순이익률', 'ROE(지배주주)', '부채비율', '당좌비율', '유보율', 'EPS(원)', 'PER(배)', 'BPS(원)', 'PBR(배)', '주당배당금(원)', '시가배당률(%)', '배당성향(%)']

# %%
annual_date
# Out:
# ['2016.12', '2017.12', '2018.12', '2019.12(E)']

# %%
quarter_date
# Out:
# ['2018.09', '2018.12', '2019.03', '2019.06', '2019.09', '2019.12(E)']

# %%
finance_data = [item.get_text().strip() for item in finance_html.select('td')]
finance_data

# 내가 원하는 모든 데이터 수를 담고 있지만 하나의 리스트 형태로 되어 있기 때문에 쉽게 분석하려면 전처리 필요
# 넘파이를 사용하면 리스트로 된 데이터를 오리지날 제무제표 정보와 같이 14X10 형태로 변환하기 가능
# Out:
# ['2,018,667',
#  '2,395,754',
#  '2,437,714',
#  '2,314,511',
#  '654,600',
#  '592,650',
#  '523,855',
#  '561,271',
#  '620,035',
#  '610,260',
#  '292,407',
#  '536,450',
#  '588,867',
#  '271,545',
#  '175,749',
#  '108,006',
#  '62,333',
#  '65,971',
#  '77,779',
#  '65,771',
#  '227,261',
#  '421,867',
#  '443,449',
#  '219,561',
#  '131,507',
#  '84,622',
#  '50,436',
#  '51,806',
#  '62,877',
#  '55,948',
#  '14.49',
#  '22.39',
#  '24.16',
#  '11.73',
#  '26.85',
#  '18.22',
#  '11.90',
#  '11.75',
#  '12.54',
#  '10.78',
#  '11.26',
#  '17.61',
#  '18.19',
#  '9.49',
#  '20.09',
#  '14.28',
#  '9.63',
#  '9.23',
#  '10.14',
#  '9.17',
#  '12.48',
#  '21.01',
#  '19.63',
#  '8.77',
#  '21.73',
#  '19.63',
#  '16.21',
#  '13.24',
#  '10.05',
#  '',
#  '35.87',
#  '40.68',
#  '36.97',
#  '',
#  '39.28',
#  '36.97',
#  '36.28',
#  '33.05',
#  '34.14',
#  '',
#  '223.46',
#  '181.61',
#  '204.12',
#  '',
#  '198.16',
#  '204.12',
#  '209.25',
#  '230.74',
#  '235.80',
#  '',
# ...

# %%
finance_data = np.array(finance_data)
finance_data.resize(len(finance_index), 10)   # resize(index개수, column개수) 왜 인덱스는 렝쓰? >>> 개수 세기 싫으니까

print(finance_data)

# 10개씩 묶은 행 개수의 리스트가 생성 됨
# Out:
# [['2,018,667' '2,395,754' '2,437,714' '2,314,511' '654,600' '592,650'
#   '523,855' '561,271' '620,035' '610,260']
#  ['292,407' '536,450' '588,867' '271,545' '175,749' '108,006' '62,333'
#   '65,971' '77,779' '65,771']
#  ['227,261' '421,867' '443,449' '219,561' '131,507' '84,622' '50,436'
#   '51,806' '62,877' '55,948']
#  ['14.49' '22.39' '24.16' '11.73' '26.85' '18.22' '11.90' '11.75' '12.54'
#   '10.78']
#  ['11.26' '17.61' '18.19' '9.49' '20.09' '14.28' '9.63' '9.23' '10.14'
#   '9.17']
#  ['12.48' '21.01' '19.63' '8.77' '21.73' '19.63' '16.21' '13.24' '10.05'
#   '']
#  ['35.87' '40.68' '36.97' '' '39.28' '36.97' '36.28' '33.05' '34.14' '']
#  ['223.46' '181.61' '204.12' '' '198.16' '204.12' '209.25' '230.74'
#   '235.80' '']
#  ['22,004.14' '24,536.12' '27,531.92' '' '27,412.63' '27,531.92'
#   '27,832.98' '28,129.35' '28,541.64' '']
#  ['2,735' '5,421' '6,024' '3,194' '1,771' '1,163' '752' '746' '899' '712']
# ...

# %%
finance_date = annual_date + quarter_date
print(finance_date)

# 두개의 리스트를 단순하게 합친거임
# Out:
# ['2016.12', '2017.12', '2018.12', '2019.12(E)', '2018.09', '2018.12', '2019.03', '2019.06', '2019.09', '2019.12(E)']

# %%
finance_html = soup.select('div.section.cop_analysis div.sub_section')[0]
finance_html
# Out:
# <div class="sub_section">
# <table class="tb_type1 tb_num tb_type1_ifrs" summary="기업실적분석에 관한표이며 주요재무정보를 최근 연간 실적, 분기 실적에 따라 정보를 제공합니다.">
# <caption>기업실적분석 테이블</caption>
# <colgroup>
# <col width="86"/>
# <col width="59"/>
# <col width="59"/>
# <col width="59"/>
# <col width="62"/>
# <col width="58"/>
# <col width="58"/>
# <col width="58"/>
# <col width="58"/>
# <col/>
# </colgroup>
# <thead>
# <tr class="t_line">
# <th class="h_th2 th_cop_anal5 b_line" rowspan="3"><strong>주요재무정보</strong></th>
# <th class="h_th2 th_cop_anal6" colspan="4" scope="col"><strong>최근 연간 실적</strong></th>
# <th class="h_th2 th_cop_anal7 last" colspan="6" scope="col"><strong>최근 분기 실적</strong></th>
# </tr>
# <tr>
# <th class="" scope="col">
# 											2016.12
# 										</th>
# <th class="" scope="col">
# 											2017.12
# 										</th>
# <th class="" scope="col">
# 											2018.12
# 										</th>
# <th class="t_line cell_strong" scope="col">
# 											2019.12<em>(E)</em>
# </th>
# ...

# %%
finance_html
# Out:
# <div class="sub_section">
# <table class="tb_type1 tb_num tb_type1_ifrs" summary="기업실적분석에 관한표이며 주요재무정보를 최근 연간 실적, 분기 실적에 따라 정보를 제공합니다.">
# <caption>기업실적분석 테이블</caption>
# <colgroup>
# <col width="86"/>
# <col width="59"/>
# <col width="59"/>
# <col width="59"/>
# <col width="62"/>
# <col width="58"/>
# <col width="58"/>
# <col width="58"/>
# <col width="58"/>
# <col/>
# </colgroup>
# <thead>
# <tr class="t_line">
# <th class="h_th2 th_cop_anal5 b_line" rowspan="3"><strong>주요재무정보</strong></th>
# <th class="h_th2 th_cop_anal6" colspan="4" scope="col"><strong>최근 연간 실적</strong></th>
# <th class="h_th2 th_cop_anal7 last" colspan="6" scope="col"><strong>최근 분기 실적</strong></th>
# </tr>
# <tr>
# <th class="" scope="col">
# 											2016.12
# 										</th>
# <th class="" scope="col">
# 											2017.12
# 										</th>
# <th class="" scope="col">
# 											2018.12
# 										</th>
# <th class="t_line cell_strong" scope="col">
# 											2019.12<em>(E)</em>
# </th>
# ...
